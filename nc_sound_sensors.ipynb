# %%
import warnings
warnings.filterwarnings('ignore')
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import Point, Polygon
import os
crs = {'init': 'epsg:4326'}
os.getcwd()
# Out:
# '/Users/sarah/Satellite_Image_Processing'

# %%
data1 = pd.read_excel('old.xlsx', header=0)
geometry1=[Point(xy) for xy in zip(data1["longitude"], data1["latitude"])]
trained = gpd.GeoDataFrame(data1, crs=crs, geometry=geometry1)

data2 = pd.read_excel('recently_added.xlsx', header =0)
geometry2=[Point(xy) for xy in zip(data2["longitude"], data2["latitude"])]
new = gpd.GeoDataFrame(data2, crs=crs, geometry=geometry2)

# %%
shape = gpd.read_file('../Downloads/tl_2023_37041_areawater/tl_2023_37041_areawater.shp')
shape = shape.to_crs('epsg:4326')

# %%
fig, ax = plt.subplots(figsize=(10,7))

shape.plot(ax=ax,alpha=0.1, edgecolor = 'k', linewidth=1)
trained.plot(ax=ax, color='k', markersize = 55, label = r'Training Site')
new.plot(ax=ax, color='r', markersize = 55, label = r'Leave Out Site')

ax.legend(loc=1)
ax.set_title(r'PlanetLabs Locations along Chowan River', fontsize=12)
ax.set_xlabel('Longitude', fontsize=10)
ax.set_ylabel('Latitude', fontsize='medium')
plt.ylim([35.97, 36.3])
plt.xlim([-76.8, -76.5])
plt.show()
# fig.savefig('Desktop/PMwf.png')

# %%
# !wget --no-check-certificate https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/world-countries.json

# %%
import json
e = json.load(open('world-countries.json','r'))

json.dump(e['features'][-10], open('us.json','w'))

# %%
# e['features'][-10]

# %%
# import pandas as pd
# import folium 
# df = pd.read_csv('soundsesnors.csv')
# # Assuming 'data' is your DataFrame with columns 'Latitude' and 'Longitude'
# coordinates = [(lat, lon) for lat, lon in zip(df['latitude'], df['longitude'])]
# m = folium.Map(location=[36.2326724, -76.698134], zoom_start=10,  tiles='CartoDB Voyager')
# for point in coordinates:
#     folium.CircleMarker(point, radius = 5, color = 'blue', fill = True).add_to(m)

# m

# %% [raw]
# data

# %%
import pandas as pd
import folium 
df = pd.read_excel('../Documents/Blooms/Potential Sites Sarah.xlsx', header=0)

coordinates = [(lat, lon) for lat, lon in zip(df['lat'], df['long'])]

m = folium.Map(location=[36.1326724, -76.4982], zoom_start=10,  tiles='CartoDB Voyager')

for index, row in df.iterrows():
    name = row['site']
    point = (row['lat'], row['long'])
    popup_text = f"<b>{name}</b>"
#     if name.startswith('new_'):
#         color = 'red'
#     elif name.startswith('maybe_'):
#         color = 'green'
#     else:
#         color = 'blue'    
    folium.CircleMarker(point, radius=5, color='blue', fill=True, popup=popup_text).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba91f2b471d09c3b70bce5de00000d11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba91f2b471d09c3b70bce5de00000d11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba91f2b471d09c3b70bce5de00000d11 = L.map(
#                 &quot;map_ba91f2b471d09c3b70bce5de00000d11&quot;,
#                 {
#                     center: [36.1326724, -76.4982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f01d96656bcf22f60fb6064979ef8d9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f01d96656bcf22f60fb6064979ef8d9.addTo(map_ba91f2b471d09c3b70bce5de00000d11);
#
#
#             var circle_marker_2c0fcf39a20cf9fdc9bd55b34656d2c7 = L.circleMarker(
#                 [36.169458, -76.751827],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba91f2b471d09c3b70bce5de00000d11);
#
#
#         var popup_3b01e4b74f0fda49b75f2f28ecd813f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3b0bf74bf2cf3a57d0d748a2ebbc4f3 = $(`&lt;div id=&quot;html_f3b0bf74bf2cf3a57d0d748a2ebbc4f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Planet1&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_3b01e4b74f0fda49b75f2f28ecd813f8.setContent(html_f3b0bf74bf2cf3a57d0d748a2ebbc4f3);
#
#
#
#         circle_marker_2c0fcf39a20cf9fdc9bd55b34656d2c7.bindPopup(popup_3b01e4b74f0fda49b75f2f28ecd813f8)
#         ;
#
#
#
#
#             var circle_marker_86276957ce8568fb0a7b8b8ad6d7b36a = L.circleMarker(
#                 [36.1432, -76.7539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba91f2b471d09c3b70bce5de00000d11);
#
#
#         var popup_52986328b47277e5c77660698d396bdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00f6ed9cff7d6c1242bf07a262b4d8dc = $(`&lt;div id=&quot;html_00f6ed9cff7d6c1242bf07a262b4d8dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Planet2&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_52986328b47277e5c77660698d396bdf.setContent(html_00f6ed9cff7d6c1242bf07a262b4d8dc);
#
#
#
#         circle_marker_86276957ce8568fb0a7b8b8ad6d7b36a.bindPopup(popup_52986328b47277e5c77660698d396bdf)
#         ;
#
#
#
#
#             var circle_marker_86fc3e87929e935bceee2d7c25e7a9b0 = L.circleMarker(
#                 [36.1386, -76.7515],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ba91f2b471d09c3b70bce5de00000d11);
#
#
#         var popup_20046cd6f95c6072f1ace45cced63985 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67d1d61d0ae0b610ac58a62038ac946e = $(`&lt;div id=&quot;html_67d1d61d0ae0b610ac58a62038ac946e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Planet3&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_20046cd6f95c6072f1ace45cced63985.setContent(html_67d1d61d0ae0b610ac58a62038ac946e);
#
#
#
#         circle_marker_86fc3e87929e935bceee2d7c25e7a9b0.bindPopup(popup_20046cd6f95c6072f1ace45cced63985)
#         ;
#
#
#
#
#             var circle_marker_e2ddaaaf113b663c433c488b1bc79e49 = L.circleMarker(
#                 [36.131761, -76.74914],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quo

# %%
import pandas as pd
import folium 
df = pd.read_csv('soundsesnors.csv')

coordinates = [(lat, lon) for lat, lon in zip(df['latitude'], df['longitude'])]

m = folium.Map(location=[36.1326724, -76.4982], zoom_start=10,  tiles='OpenStreetMap')

for index, row in df.iterrows():
    name = row['SITE']
    point = (row['latitude'], row['longitude'])
    popup_text = f"<b>{name}</b>"
    if name.startswith('D'):
        color = 'red'
    
    else:
        color = 'blue'    
    folium.CircleMarker(point, radius=5, color=color, fill=True, popup=popup_text).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9531ed152905a8560860f66d414454a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9531ed152905a8560860f66d414454a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9531ed152905a8560860f66d414454a3 = L.map(
#                 &quot;map_9531ed152905a8560860f66d414454a3&quot;,
#                 {
#                     center: [36.1326724, -76.4982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9d55f09e6517459b67bbeb2c26c629f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9d55f09e6517459b67bbeb2c26c629f.addTo(map_9531ed152905a8560860f66d414454a3);
#
#
#             var circle_marker_ace063519bd8cc45fe8689e7fbd00fb6 = L.circleMarker(
#                 [36.2326724, -76.698134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9531ed152905a8560860f66d414454a3);
#
#
#         var popup_eee03612e71ca4bc3dc2724b16a0fbf2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_269196fb2e7f6f2ba8e9b4d741a0c452 = $(`&lt;div id=&quot;html_269196fb2e7f6f2ba8e9b4d741a0c452&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Arrowhead Beach&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_eee03612e71ca4bc3dc2724b16a0fbf2.setContent(html_269196fb2e7f6f2ba8e9b4d741a0c452);
#
#
#
#         circle_marker_ace063519bd8cc45fe8689e7fbd00fb6.bindPopup(popup_eee03612e71ca4bc3dc2724b16a0fbf2)
#         ;
#
#
#
#
#             var circle_marker_a2b867d1f8024c6942356069fff035e1 = L.circleMarker(
#                 [36.272006, -76.675842],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9531ed152905a8560860f66d414454a3);
#
#
#         var popup_225c448c700aa1a4d4f86d83764b7440 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_24287c01aebb581e488bb7223cb3587d = $(`&lt;div id=&quot;html_24287c01aebb581e488bb7223cb3587d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cannons Ferry&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_225c448c700aa1a4d4f86d83764b7440.setContent(html_24287c01aebb581e488bb7223cb3587d);
#
#
#
#         circle_marker_a2b867d1f8024c6942356069fff035e1.bindPopup(popup_225c448c700aa1a4d4f86d83764b7440)
#         ;
#
#
#
#
#             var circle_marker_d881fa3b955f6dbe5349f789db45d09c = L.circleMarker(
#                 [36.184133, -76.722858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9531ed152905a8560860f66d414454a3);
#
#
#         var popup_8439f0266b14f9b1dd1cd84020dadb38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_960286a914cc20be29fa8e47c24c3c48 = $(`&lt;div id=&quot;html_960286a914cc20be29fa8e47c24c3c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rocky Hock Lane&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_8439f0266b14f9b1dd1cd84020dadb38.setContent(html_960286a914cc20be29fa8e47c24c3c48);
#
#
#
#         circle_marker_d881fa3b955f6dbe5349f789db45d09c.bindPopup(popup_8439f0266b14f9b1dd1cd84020dadb38)
#         ;
#
#
#
#
#             var circle_marker_0c30b7f061716fe00e679fec22498da0 = L.circleMarker(
#                 [36.055163, -76.69076],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quo

# %%
m.save('updated_map.html')
